# %%
import glob
flist = glob.glob("airbnb/*.csv")
flist
# Out:
# ['airbnb\\Beijing_reviews.csv', 'airbnb\\Berlin_reviews.csv']

# %%
import pandas as pd
pd.read_csv(flist[0], encoding="utf-8")
# Out:
#         listing_id         id        date  reviewer_id   reviewer_name  \
# 0            44054      84748  2010-08-25       207019          Jarrod
# 1            44054     118384  2010-10-13       218723        Kimberly
# 2            44054     436978  2011-08-11       609177            Emma
# 3            44054    1118657  2012-04-12      1787536        Andreyna
# 4            44054    2140650  2012-08-30      1179565         Frances
# 5            44054    2439478  2012-09-28      2328151         Ricardo
# 6            44054    2507676  2012-10-04      3659992         Patrick
# 7            44054    2886867  2012-11-15      3725353           Zahra
# 8            44054    3722573  2013-03-08      1988718           Petar
# 9            44054    4447534  2013-05-06      2824806            Emil
# 10           44054    4532301  2013-05-11      4785856        Nathalie
# 11           44054    4633069  2013-05-17      4949190         Clement
# 12           44054    4691155  2013-05-20      5616684            Lisa
# 13           44054    5522710  2013-07-04      4886951         Michael
# 14           44054    7889794  2013-10-07      8891330            Eric
# 15           44054    8579436  2013-11-05      4686354          Jeremy
# 16           44054    8781380  2013-11-18      3242703             Kay
# 17           44054   10730961  2014-03-04       965610           Sonia
# 18           44054   11509900  2014-04-06     12174008             Jim
# 19           44054   11756231  2014-04-14      4050438  Brad & Monique
# 20           44054   20039247  2014-09-22     12200151         Jocelyn
# 21           44054   20734583  2014-10-05     14540449          Sharon
# 22           44054   21824996  2014-10-25      4118113       Lily & Ad
# 23           44054   24116762  2014-12-20     24435659            Mike
# 24           44054   36662064  2015-06-30     11634304         Bethany
# 25           44054   48935090  2015-09-29      3766599   Kelly-Eleanor
# 26           44054   50889241  2015-10-15     35112509            Rong
# 27           44054   51499560  2015-10-20     46381110         Cathryn
# 28           44054   52657120  2015-10-31     24379821              金峰
# 29           44054   54066571  2015-11-15     33467823         Yanchen
# ...            ...        ...         ...          ...             ...
# 159009    29886313  346633442  2018-11-09    108018318              楠楠
# 159010    29892264  347233397  2018-11-11    218375126          Bright
# 159011    29893583  347166198  2018-11-11    221274297              红巧
# 159012    29897949  346794679  2018-11-10    219546110              发煊
# 159013    29910009  347850316  2018-11-12     70475875              咩咩
# 159014    29910277  347233671  2018-11-11    199363705          Bailly
# 159015    29910616  348490727  2018-11-14    225556487              宗莲
# 159016    29910616  348713397  2018-11-15    225723789               润
# 159017    29910717  346850539  2018-11-10    224920621              梦杰
# 159018    29910717  347235813  2018-11-11    225060304              文杰
# 159019    29931314  348228494  2018-11-13     83149431           Zheng
# 159020    29932439  348468063  2018-11-14    225226717               聂
# 159021    29937219  348707862  2018-11-15    207706965            Emma
# 159022    29940393  348692662  2018-11-15    224651666              成臻
# 159023    29942100  348214140  2018-11-13    221324724               铮
# 159024    29942100  348456346  2018-11-14    164265715               王
# 159025    29942100  348715368  2018-11-15    225565421               A
# 159026    29945819  348209253  2018-11-13     49234589              麦子
# 159027    29953737  348220996  2018-11-13    205176722               陈
# 159028    29953737  348479307  2018-11-14     22374791           Grace
# 159029    29953737  348723686  2018-11-15     96800717              爽冰
# 159030    29954620  348215043  2018-11-13    225154980              美连
# 159031    29957748  348194530  2018-11-12    222483876          Yuyuko
# 159032    29969289  348486875  2018-11-14    222342988              富洋
# 159033    29975983  348751622  2018-11-15    140602656              Hy
# 159034    29978542  348706842  2018-11-15    193578243               涛
# 159035    29979243  348466439  2018-11-14     87848321              跃欣
# 159036    29979243  348718243  2018-11-15    208625705              春雨
# 159037    29979416  348463406  2018-11-14     76503574            Lynn
# 159038    29982660  348722818  2018-11-15    188279834              万婷
#
#                                                  comments
# 0       Sev was very helpful.  Sev showed us where to ...
# 1       We arrived in Beijing very early in the mornin...
# 2       It is a really massive apartment and really co...
# 3       Sev was incredibly helpful, showed us around t...
# 4       The appartment was ideal for our party of 6 ad...
# 5       Nice place to stay when travelling in a group ...
# 6       We had a great experience in Beijing.  The apa...
# 7       The apartment was exactly what I expected (as ...
# 8       Definitely the place to stay when in Beijing. ...
# 9       We had a great time staying at Sev's apparteme...
# 10      We recommend East apartments. Sev was great or...
# 11      very good, the appartement looks exactly as de...
# 12      This was my very first AirBnB stay and it was ...
# 13      East Apartments is a wonderful Chinese communi...
# 14      good location, just 5-7min walk from the subwa...
# 15      The apartment worked out perfectly for us. It ...
# 16      spacious apartment and clean.. just a nice pla...
# 17      Very nice and super clean apt. Sev is super re...
# 18      Apartment was spacious, clean and set in an at...
# 19      The listing was great for our group and it was...
# 20      Great location, easy to go to the famous attra...
# 21      We were made feel very welcomed. Appartment is...
# 22      Sev was zelf ter plaatse om de sleutel te over...
# 23      Service excellent.  Internet connection not ve...
# 24      The host was helpful in letting us in and show...
# 25      Apartment was larger than expected and in a go...
# 26      非常美好的一次入住体验,我们两家带着孩子和老人一共五大两小,在那里住的非常舒服,还给宝宝熬了...
# 27      Nice apartment. Some problem about the date of...
# 28             房子非常好~小区非常棒~离地铁站非常近~~设施非常齐全~~服务非常到位~~完全满意~
# 29            房间外面看的景色不错,就是洗澡的龙头有点高,房间很好.很舒服,第一次来北京,暖气很足~
# ...                                                   ...
# 159009  The host canceled this reservation 42 days bef...
# 159010                                 环境很好,装修也很好,比预期要好很多
# 159011             环境不错,交通便利,出门就是地铁站,房子很大很干净,住着舒心,以后还会选择｡
# 159012  我是她们的第一个客人哦!小姐姐长得特漂亮,人又特别好,待人热情真诚,很容易给人一种亲切感,一...
# 159013  在三里屯玩后 比较晚预定的 感谢房东细心的引导入住,虽然晚上黑 但还是很好找｡房子很干净 无...
# 159014              房间明亮宽敞,房东小姐姐人很好,回复及时,沟通也很愉快,入住体验nice~
# 159015  首先说房间设施,都很齐全,设备也很好,第二说位置,很好找,附近公交地铁都很方便｡地铁走路两三...
# 159016  交通非常便利,房间干净整洁,房东热情友好,而且还帮忙推荐最适合的行程,总之,炒鸡 nice ...
# 159017  装修看起来很有档次,房间里面干干净净的,做饭,洗衣服等等能在家里做的都可以做,有种家的感觉,...
# 159018  房屋设施齐全,地理位置很好,最最最重要的是非常干净整洁,床品也都是一客一换,对于我这种有轻微...
# 159019                                挺好的,价格合适,装修舒服,位置也好找
# 159020  本人有点轻微洁癖,所以在订房前先约了房东看房｡房东给我的第一印象是一个恬静温婉的女生,这让我...
# 159021                                             房主热情好客
# 159022                                            干净整洁有绿植
# 159023  半夜到房间,自助入住就可以,楼下酒店有停车场,房子离三里屯soho就三四百米的距离,对面就是...
# 159024  地理位置很便利,离soho非常近｡\n在酒店楼上,很安全｡装修风格很干净,日系｡厨房油盐酱醋...
# 159025  首先地理位置特别棒 距离太古里非常近 然后住宿条件非常干净非常安全沐浴用品厨房用品非常全  ...
# 159026                               小屋很温暖很干净,交通也方便,住着很舒服
# 159027  房子整体装修的特别好,很温馨,感觉像是回了家｡我订的这个房间挺大的,床是1米8的,独立卫生间...
# 159028  房东的房子装修得很棒,公共空间很大,而且很温馨,像家的感觉｡厨房设施等很齐全｡公共空间有空气...
# 159029       房间很漂亮,床睡的超舒服,暖气特别热｡卫生间浴缸很干净,热水充足｡房东姐姐很好客｡推荐!
# 159030  性价比很高的民宿,非常满意,房子很漂亮,装饰布置好用心,床品也很舒服,位置就在前门旁边,去天...
# 159031  The host canceled this reservation 3 days befo...
# 159032  第二次入住了,服务态度依旧好,性价比颇高的房源! 适合一人到四个人入住; 入户也很方便,密码...
# 159033  The host canceled this reservation 5 days befo...
# 159034  房东人很热情,很认真,准时接站,细节安排的很好,感谢,感谢,小区环境不错,离火车很近,超级方...
# 159035  作为一个建筑设计师,第一次给房东留言｡房东服务特别周到,房间布局构思巧妙,超级温馨｡里面的装...
# 159036  首先,这个风格真的很好,我们一共四个人一起住的榻榻米,很舒服｡其次里面提供了很多娱乐的活动,...
# 159037                              位置交通方便,房东热情,住得很舒心｡谢谢｡
# 159038  距离将台,东风北桥地铁都不远,位置方便｡房东热情好客,还给准备了水果｡在这里住和家里一样｡有...
#
# [159039 rows x 6 columns]

# %%
# Concat第一種寫法
df = None
for fn in flist:
    temp = pd.read_csv(fn, encoding="utf-8")
    # 第一個csv -> df設定成第一個
    if df is None:
        df = temp
    # 第二個csv以後 -> 嫁接到原本的csv
    else:
        df = pd.concat([df, temp], axis=0, ignore_index=True)
df
# Out:
#         listing_id         id        date  reviewer_id   reviewer_name  \
# 0            44054      84748  2010-08-25       207019          Jarrod
# 1            44054     118384  2010-10-13       218723        Kimberly
# 2            44054     436978  2011-08-11       609177            Emma
# 3            44054    1118657  2012-04-12      1787536        Andreyna
# 4            44054    2140650  2012-08-30      1179565         Frances
# 5            44054    2439478  2012-09-28      2328151         Ricardo
# 6            44054    2507676  2012-10-04      3659992         Patrick
# 7            44054    2886867  2012-11-15      3725353           Zahra
# 8            44054    3722573  2013-03-08      1988718           Petar
# 9            44054    4447534  2013-05-06      2824806            Emil
# 10           44054    4532301  2013-05-11      4785856        Nathalie
# 11           44054    4633069  2013-05-17      4949190         Clement
# 12           44054    4691155  2013-05-20      5616684            Lisa
# 13           44054    5522710  2013-07-04      4886951         Michael
# 14           44054    7889794  2013-10-07      8891330            Eric
# 15           44054    8579436  2013-11-05      4686354          Jeremy
# 16           44054    8781380  2013-11-18      3242703             Kay
# 17           44054   10730961  2014-03-04       965610           Sonia
# 18           44054   11509900  2014-04-06     12174008             Jim
# 19           44054   11756231  2014-04-14      4050438  Brad & Monique
# 20           44054   20039247  2014-09-22     12200151         Jocelyn
# 21           44054   20734583  2014-10-05     14540449          Sharon
# 22           44054   21824996  2014-10-25      4118113       Lily & Ad
# 23           44054   24116762  2014-12-20     24435659            Mike
# 24           44054   36662064  2015-06-30     11634304         Bethany
# 25           44054   48935090  2015-09-29      3766599   Kelly-Eleanor
# 26           44054   50889241  2015-10-15     35112509            Rong
# 27           44054   51499560  2015-10-20     46381110         Cathryn
# 28           44054   52657120  2015-10-31     24379821              金峰
# 29           44054   54066571  2015-11-15     33467823         Yanchen
# ...            ...        ...         ...          ...             ...
# 560972    29628409  343342304  2018-10-31     46447567            Ines
# 560973    29628409  344678306  2018-11-04    169652131           Zeina
# 560974    29628409  345482795  2018-11-05    223211554            Luca
# 560975    29638719  344350290  2018-11-03     10896398          Stefan
# 560976    29640657  342876331  2018-10-29     96130107        Sy'raazy
# 560977    29640657  343947591  2018-11-02    222267323         Shriram
# 560978    29640657  345497600  2018-11-05     72296860          Lenard
# 560979    29649077  343017577  2018-10-30     75881312      José Pedro
# 560980    29664434  345546971  2018-11-05     19126626             Jan
# 560981    29665300  344950676  2018-11-04     20934453          Rafael
# 560982    29671442  345448737  2018-11-05     46801414          Jeanne
# 560983    29671651  344698596  2018-11-04    126216497            Nico
# 560984    29680856  344282545  2018-11-03     51257197            Andy
# 560985    29698020  343539983  2018-11-01     17753935          Oliver
# 560986    29705786  345890494  2018-11-06    224475662       Sebastian
# 560987    29710765  344899380  2018-11-04     76295406           Roman
# 560988    29721020  344679554  2018-11-04     36693253             Hai
# 560989    29732182  344371983  2018-11-03    161032365          Alexis
# 560990    29740105  345002170  2018-11-04    199876443          Adrian
# 560991    29759681  345945807  2018-11-06     91221067      Lauren Jay
# 560992    29772631  344733429  2018-11-04     13204769       Christina
# 560993    29784461  345903456  2018-11-06    177815455       Asger Thy
# 560994    29784461  345903701  2018-11-06    188839753           Katie
# 560995    29784461  345903921  2018-11-06    224121530        Brigitte
# 560996    29784461  345904101  2018-11-06      7407331           Gerco
# 560997    29784461  345904235  2018-11-06    160580302        Michelle
# 560998    29792124  345428291  2018-11-05    117705698           Kevin
# 560999    29817383  346045092  2018-11-07     20344466           Johan
# 561000    29849565  346027793  2018-11-07    114291292        Matthias
# 561001    29849565  346048710  2018-11-07     10938217         Mélanie
#
#                                                  comments
# 0       Sev was very helpful.  Sev showed us where to ...
# 1       We arrived in Beijing very early in the mornin...
# 2       It is a really massive apartment and really co...
# 3       Sev was incredibly helpful, showed us around t...
# 4       The appartment was ideal for our party of 6 ad...
# 5       Nice place to stay when travelling in a group ...
# 6       We had a great experience in Beijing.  The apa...
# 7       The apartment was exactly what I expected (as ...
# 8       Definitely the place to stay when in Beijing. ...
# 9       We had a great time staying at Sev's apparteme...
# 10      We recommend East apartments. Sev was great or...
# 11      very good, the appartement looks exactly as de...
# 12      This was my very first AirBnB stay and it was ...
# 13      East Apartments is a wonderful Chinese communi...
# 14      good location, just 5-7min walk from the subwa...
# 15      The apartment worked out perfectly for us. It ...
# 16      spacious apartment and clean.. just a nice pla...
# 17      Very nice and super clean apt. Sev is super re...
# 18      Apartment was spacious, clean and set in an at...
# 19      The listing was great for our group and it was...
# 20      Great location, easy to go to the famous attra...
# 21      We were made feel very welcomed. Appartment is...
# 22      Sev was zelf ter plaatse om de sleutel te over...
# 23      Service excellent.  Internet connection not ve...
# 24      The host was helpful in letting us in and show...
# 25      Apartment was larger than expected and in a go...
# 26      非常美好的一次入住体验,我们两家带着孩子和老人一共五大两小,在那里住的非常舒服,还给宝宝熬了...
# 27      Nice apartment. Some problem about the date of...
# 28             房子非常好~小区非常棒~离地铁站非常近~~设施非常齐全~~服务非常到位~~完全满意~
# 29            房间外面看的景色不错,就是洗澡的龙头有点高,房间很好.很舒服,第一次来北京,暖气很足~
# ...                                                   ...
# 560972  Everything nice and clean. Very friendly and e...
# 560973  very clean and a good value for two Nicola is ...
# 560974  The host is friendly. The place was bigger and...
# 560975  Mathias ist ein super Gastgeber. Ich kann ihn ...
# 560976  The host canceled this reservation 55 days bef...
# 560977  Great place to stay and a bit far though. Valu...
# 560978  The place is great. Very spacey and clean, wit...
# 560979  The host canceled this reservation 69 days bef...
# 560980  This Appartment is super comfortable and Claud...
# 560981  Top Lage. Sehr netter Gastgeber. Preis sehr st...
# 560982  The host canceled this reservation 4 days befo...
# 560983           Tolles Zimmer. Alles sehr unkompliziert.
# 560984  Sehr zu empfehlen. Süße kleine Wohnung, ideal ...
# 560985  The host canceled this reservation 28 days bef...
# 560986  The host canceled this reservation 24 days bef...
# 560987  Diese Unterkunft kann ich nur empfehlen. Der G...
# 560988         Nice, quite close to the center - 15m walk
# 560989  The host canceled this reservation 54 days bef...
# 560990                            Alles ok, gerne wieder.
# 560991  The host canceled this reservation 55 days bef...
# 560992  The host canceled this reservation 13 days bef...
# 560993  The host canceled this reservation 52 days bef...
# 560994  The host canceled this reservation 7 days befo...
# 560995  The host canceled this reservation 11 days bef...
# 560996  The host canceled this reservation 32 days bef...
# 560997  The host canceled this reservation 269 days be...
# 560998  The host canceled this reservation 5 days befo...
# 560999  The host canceled this reservation 50 days bef...
# 561000  The host canceled this reservation 23 days bef...
# 561001  The host canceled this reservation 51 days bef...
#
# [561002 rows x 6 columns]

# %%
# 先準備等一下要接所有csv的list
alldf = []
for fn in flist:
    # 每讀一個, 就把它丟進list
    temp = pd.read_csv(fn, encoding="utf-8")
    alldf.append(temp)
# 最後一次concat
df2 = pd.concat(alldf, axis=0, ignore_index=True)
df2
# Out:
#         listing_id         id        date  reviewer_id   reviewer_name  \
# 0            44054      84748  2010-08-25       207019          Jarrod
# 1            44054     118384  2010-10-13       218723        Kimberly
# 2            44054     436978  2011-08-11       609177            Emma
# 3            44054    1118657  2012-04-12      1787536        Andreyna
# 4            44054    2140650  2012-08-30      1179565         Frances
# 5            44054    2439478  2012-09-28      2328151         Ricardo
# 6            44054    2507676  2012-10-04      3659992         Patrick
# 7            44054    2886867  2012-11-15      3725353           Zahra
# 8            44054    3722573  2013-03-08      1988718           Petar
# 9            44054    4447534  2013-05-06      2824806            Emil
# 10           44054    4532301  2013-05-11      4785856        Nathalie
# 11           44054    4633069  2013-05-17      4949190         Clement
# 12           44054    4691155  2013-05-20      5616684            Lisa
# 13           44054    5522710  2013-07-04      4886951         Michael
# 14           44054    7889794  2013-10-07      8891330            Eric
# 15           44054    8579436  2013-11-05      4686354          Jeremy
# 16           44054    8781380  2013-11-18      3242703             Kay
# 17           44054   10730961  2014-03-04       965610           Sonia
# 18           44054   11509900  2014-04-06     12174008             Jim
# 19           44054   11756231  2014-04-14      4050438  Brad & Monique
# 20           44054   20039247  2014-09-22     12200151         Jocelyn
# 21           44054   20734583  2014-10-05     14540449          Sharon
# 22           44054   21824996  2014-10-25      4118113       Lily & Ad
# 23           44054   24116762  2014-12-20     24435659            Mike
# 24           44054   36662064  2015-06-30     11634304         Bethany
# 25           44054   48935090  2015-09-29      3766599   Kelly-Eleanor
# 26           44054   50889241  2015-10-15     35112509            Rong
# 27           44054   51499560  2015-10-20     46381110         Cathryn
# 28           44054   52657120  2015-10-31     24379821              金峰
# 29           44054   54066571  2015-11-15     33467823         Yanchen
# ...            ...        ...         ...          ...             ...
# 401933    29628409  343342304  2018-10-31     46447567            Ines
# 401934    29628409  344678306  2018-11-04    169652131           Zeina
# 401935    29628409  345482795  2018-11-05    223211554            Luca
# 401936    29638719  344350290  2018-11-03     10896398          Stefan
# 401937    29640657  342876331  2018-10-29     96130107        Sy'raazy
# 401938    29640657  343947591  2018-11-02    222267323         Shriram
# 401939    29640657  345497600  2018-11-05     72296860          Lenard
# 401940    29649077  343017577  2018-10-30     75881312      José Pedro
# 401941    29664434  345546971  2018-11-05     19126626             Jan
# 401942    29665300  344950676  2018-11-04     20934453          Rafael
# 401943    29671442  345448737  2018-11-05     46801414          Jeanne
# 401944    29671651  344698596  2018-11-04    126216497            Nico
# 401945    29680856  344282545  2018-11-03     51257197            Andy
# 401946    29698020  343539983  2018-11-01     17753935          Oliver
# 401947    29705786  345890494  2018-11-06    224475662       Sebastian
# 401948    29710765  344899380  2018-11-04     76295406           Roman
# 401949    29721020  344679554  2018-11-04     36693253             Hai
# 401950    29732182  344371983  2018-11-03    161032365          Alexis
# 401951    29740105  345002170  2018-11-04    199876443          Adrian
# 401952    29759681  345945807  2018-11-06     91221067      Lauren Jay
# 401953    29772631  344733429  2018-11-04     13204769       Christina
# 401954    29784461  345903456  2018-11-06    177815455       Asger Thy
# 401955    29784461  345903701  2018-11-06    188839753           Katie
# 401956    29784461  345903921  2018-11-06    224121530        Brigitte
# 401957    29784461  345904101  2018-11-06      7407331           Gerco
# 401958    29784461  345904235  2018-11-06    160580302        Michelle
# 401959    29792124  345428291  2018-11-05    117705698           Kevin
# 401960    29817383  346045092  2018-11-07     20344466           Johan
# 401961    29849565  346027793  2018-11-07    114291292        Matthias
# 401962    29849565  346048710  2018-11-07     10938217         Mélanie
#
#                                                  comments
# 0       Sev was very helpful.  Sev showed us where to ...
# 1       We arrived in Beijing very early in the mornin...
# 2       It is a really massive apartment and really co...
# 3       Sev was incredibly helpful, showed us around t...
# 4       The appartment was ideal for our party of 6 ad...
# 5       Nice place to stay when travelling in a group ...
# 6       We had a great experience in Beijing.  The apa...
# 7       The apartment was exactly what I expected (as ...
# 8       Definitely the place to stay when in Beijing. ...
# 9       We had a great time staying at Sev's apparteme...
# 10      We recommend East apartments. Sev was great or...
# 11      very good, the appartement looks exactly as de...
# 12      This was my very first AirBnB stay and it was ...
# 13      East Apartments is a wonderful Chinese communi...
# 14      good location, just 5-7min walk from the subwa...
# 15      The apartment worked out perfectly for us. It ...
# 16      spacious apartment and clean.. just a nice pla...
# 17      Very nice and super clean apt. Sev is super re...
# 18      Apartment was spacious, clean and set in an at...
# 19      The listing was great for our group and it was...
# 20      Great location, easy to go to the famous attra...
# 21      We were made feel very welcomed. Appartment is...
# 22      Sev was zelf ter plaatse om de sleutel te over...
# 23      Service excellent.  Internet connection not ve...
# 24      The host was helpful in letting us in and show...
# 25      Apartment was larger than expected and in a go...
# 26      非常美好的一次入住体验,我们两家带着孩子和老人一共五大两小,在那里住的非常舒服,还给宝宝熬了...
# 27      Nice apartment. Some problem about the date of...
# 28             房子非常好~小区非常棒~离地铁站非常近~~设施非常齐全~~服务非常到位~~完全满意~
# 29            房间外面看的景色不错,就是洗澡的龙头有点高,房间很好.很舒服,第一次来北京,暖气很足~
# ...                                                   ...
# 401933  Everything nice and clean. Very friendly and e...
# 401934  very clean and a good value for two Nicola is ...
# 401935  The host is friendly. The place was bigger and...
# 401936  Mathias ist ein super Gastgeber. Ich kann ihn ...
# 401937  The host canceled this reservation 55 days bef...
# 401938  Great place to stay and a bit far though. Valu...
# 401939  The place is great. Very spacey and clean, wit...
# 401940  The host canceled this reservation 69 days bef...
# 401941  This Appartment is super comfortable and Claud...
# 401942  Top Lage. Sehr netter Gastgeber. Preis sehr st...
# 401943  The host canceled this reservation 4 days befo...
# 401944           Tolles Zimmer. Alles sehr unkompliziert.
# 401945  Sehr zu empfehlen. Süße kleine Wohnung, ideal ...
# 401946  The host canceled this reservation 28 days bef...
# 401947  The host canceled this reservation 24 days bef...
# 401948  Diese Unterkunft kann ich nur empfehlen. Der G...
# 401949         Nice, quite close to the center - 15m walk
# 401950  The host canceled this reservation 54 days bef...
# 401951                            Alles ok, gerne wieder.
# 401952  The host canceled this reservation 55 days bef...
# 401953  The host canceled this reservation 13 days bef...
# 401954  The host canceled this reservation 52 days bef...
# 401955  The host canceled this reservation 7 days befo...
# 401956  The host canceled this reservation 11 days bef...
# 401957  The host canceled this reservation 32 days bef...
# 401958  The host canceled this reservation 269 days be...
# 401959  The host canceled this reservation 5 days befo...
# 401960  The host canceled this reservation 50 days bef...
# 401961  The host canceled this reservation 23 days bef...
# 401962  The host canceled this reservation 51 days bef...
#
# [561002 rows x 6 columns]

# %%
# 行操作
df["date"]
# Out:
# 0         2010-08-25
# 1         2010-10-13
# 2         2011-08-11
# 3         2012-04-12
# 4         2012-08-30
# 5         2012-09-28
# 6         2012-10-04
# 7         2012-11-15
# 8         2013-03-08
# 9         2013-05-06
# 10        2013-05-11
# 11        2013-05-17
# 12        2013-05-20
# 13        2013-07-04
# 14        2013-10-07
# 15        2013-11-05
# 16        2013-11-18
# 17        2014-03-04
# 18        2014-04-06
# 19        2014-04-14
# 20        2014-09-22
# 21        2014-10-05
# 22        2014-10-25
# 23        2014-12-20
# 24        2015-06-30
# 25        2015-09-29
# 26        2015-10-15
# 27        2015-10-20
# 28        2015-10-31
# 29        2015-11-15
#              ...
# 401933    2018-10-31
# 401934    2018-11-04
# 401935    2018-11-05
# 401936    2018-11-03
# 401937    2018-10-29
# 401938    2018-11-02
# 401939    2018-11-05
# 401940    2018-10-30
# 401941    2018-11-05
# 401942    2018-11-04
# 401943    2018-11-05
# 401944    2018-11-04
# 401945    2018-11-03
# 401946    2018-11-01
# 401947    2018-11-06
# 401948    2018-11-04
# 401949    2018-11-04
# 401950    2018-11-03
# 401951    2018-11-04
# 401952    2018-11-06
# 401953    2018-11-04
# 401954    2018-11-06
# 401955    2018-11-06
# 401956    2018-11-06
# 401957    2018-11-06
# 401958    2018-11-06
# 401959    2018-11-05
# 401960    2018-11-07
# 401961    2018-11-07
# 401962    2018-11-07
# Name: date, Length: 561002, dtype: object

# %%
# 多個行 [ [] ] 外面[]: 行操作 裡面[]: 把欄位組合成一個list
df[ ["id", "date"] ]
# Out:
#                id        date
# 0           84748  2010-08-25
# 1          118384  2010-10-13
# 2          436978  2011-08-11
# 3         1118657  2012-04-12
# 4         2140650  2012-08-30
# 5         2439478  2012-09-28
# 6         2507676  2012-10-04
# 7         2886867  2012-11-15
# 8         3722573  2013-03-08
# 9         4447534  2013-05-06
# 10        4532301  2013-05-11
# 11        4633069  2013-05-17
# 12        4691155  2013-05-20
# 13        5522710  2013-07-04
# 14        7889794  2013-10-07
# 15        8579436  2013-11-05
# 16        8781380  2013-11-18
# 17       10730961  2014-03-04
# 18       11509900  2014-04-06
# 19       11756231  2014-04-14
# 20       20039247  2014-09-22
# 21       20734583  2014-10-05
# 22       21824996  2014-10-25
# 23       24116762  2014-12-20
# 24       36662064  2015-06-30
# 25       48935090  2015-09-29
# 26       50889241  2015-10-15
# 27       51499560  2015-10-20
# 28       52657120  2015-10-31
# 29       54066571  2015-11-15
# ...           ...         ...
# 401933  343342304  2018-10-31
# 401934  344678306  2018-11-04
# 401935  345482795  2018-11-05
# 401936  344350290  2018-11-03
# 401937  342876331  2018-10-29
# 401938  343947591  2018-11-02
# 401939  345497600  2018-11-05
# 401940  343017577  2018-10-30
# 401941  345546971  2018-11-05
# 401942  344950676  2018-11-04
# 401943  345448737  2018-11-05
# 401944  344698596  2018-11-04
# 401945  344282545  2018-11-03
# 401946  343539983  2018-11-01
# 401947  345890494  2018-11-06
# 401948  344899380  2018-11-04
# 401949  344679554  2018-11-04
# 401950  344371983  2018-11-03
# 401951  345002170  2018-11-04
# 401952  345945807  2018-11-06
# 401953  344733429  2018-11-04
# 401954  345903456  2018-11-06
# 401955  345903701  2018-11-06
# 401956  345903921  2018-11-06
# 401957  345904101  2018-11-06
# 401958  345904235  2018-11-06
# 401959  345428291  2018-11-05
# 401960  346045092  2018-11-07
# 401961  346027793  2018-11-07
# 401962  346048710  2018-11-07
#
# [561002 rows x 2 columns]

# %%
# 列操作
df.head(5)
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       44054    84748  2010-08-25       207019        Jarrod
# 1       44054   118384  2010-10-13       218723      Kimberly
# 2       44054   436978  2011-08-11       609177          Emma
# 3       44054  1118657  2012-04-12      1787536      Andreyna
# 4       44054  2140650  2012-08-30      1179565       Frances
#
#                                             comments
# 0  Sev was very helpful.  Sev showed us where to ...
# 1  We arrived in Beijing very early in the mornin...
# 2  It is a really massive apartment and really co...
# 3  Sev was incredibly helpful, showed us around t...
# 4  The appartment was ideal for our party of 6 ad...

# %%
df.tail(5)
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 401958    29784461  345904235  2018-11-06    160580302      Michelle
# 401959    29792124  345428291  2018-11-05    117705698         Kevin
# 401960    29817383  346045092  2018-11-07     20344466         Johan
# 401961    29849565  346027793  2018-11-07    114291292      Matthias
# 401962    29849565  346048710  2018-11-07     10938217       Mélanie
#
#                                                  comments
# 401958  The host canceled this reservation 269 days be...
# 401959  The host canceled this reservation 5 days befo...
# 401960  The host canceled this reservation 50 days bef...
# 401961  The host canceled this reservation 23 days bef...
# 401962  The host canceled this reservation 51 days bef...

# %%
# .iloc -> [第一列, 第二列, 第三列]
# 第五列
df.iloc[4]
# Out:
# listing_id                                                   44054
# id                                                         2140650
# date                                                    2012-08-30
# reviewer_id                                                1179565
# reviewer_name                                              Frances
# comments         The appartment was ideal for our party of 6 ad...
# Name: 4, dtype: object

# %%
# 以前我們用的
import random
# 0~100(包含)
random.randint(0, 100)
# Out:
# 77

# %%
# numpy: 讓你來處理大量數字
import numpy as np
# 0~99(100不包含)
np.random.randint(0, 100, 5)
# Out:
# array([66, 29, 98, 28, 51])

# %%
# 列, 行　tuple
df.shape
# Out:
# (561002, 6)

# %%
idx = np.random.randint(0, df.shape[0], 5)
df.iloc[idx]
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 398924    27867799  334542003  2018-10-09    176150801         Janos
# 75147     18406263  291510995  2018-07-16    201325907           曹伟成
# 311058    17804004  290924241  2018-07-15       159373       Gustavo
# 131012    24487788  312176938  2018-08-23     81546296         Erick
# 258391    13872278  132004198  2017-02-15     19705661      Jennifer
#
#                                                  comments
# 398924  It was perfect. \nThe apartment was easy to ac...
# 75147                                                 都还好
# 311058  I have stayed with a friend at Martin´s appart...
# 131012  Lydia is a very helpful host, she's very respo...
# 258391  Our stay was lovely! Kirsten's home is beautif...

# %%
sample = """Amazing flat, really close from the MAS Musem, and 15 minutes walking from the Cathedral. 

Really calm, many space and light, perfect for 2 couples, perfect for a weekend.
"""
from rake_nltk import Rake
r = Rake() # Uses stopwords for english from NLTK, and all puntuation characters.
r.extract_keywords_from_text(sample)
r.get_ranked_phrases()
# Out:
# ['15 minutes walking',
#  'really close',
#  'really calm',
#  'mas musem',
#  'many space',
#  'amazing flat',
#  '2 couples',
#  'weekend',
#  'perfect',
#  'light',
#  'cathedral']

# %%
# 定義一個流程 -> 對所有格子始用這個流程(Series.apply)
def analyze(s):
    r = Rake() # Uses stopwords for english from NLTK, and all puntuation characters.
    r.extract_keywords_from_text(s)
    return str(r.get_ranked_phrases()) 
# df["comments"].head(10).astype(str).apply(analyze)
df["key_phrase"] = df["comments"].astype(str).apply(analyze)
df.to_csv("key_phrase.csv", encoding="utf-8", index=False)
df
